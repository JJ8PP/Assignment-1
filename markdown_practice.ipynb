# %% [markdown]
# <a href="https://colab.research.google.com/github/JJ8PP/Assignment-1/blob/main/markdown_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Markdown Practice in Jupyter

# %% [markdown]
# ## Sub-headings
#
# *   A
# *   B
#
#
# 1.   A item
# 2.   B item
#
#
# ![image.png](data:image/png;base64,...)
#
# **Bold** and *italic* text
